# %% [markdown]
# <a href="https://colab.research.google.com/github/Dusein/MachineLearningTask/blob/main/6WeekTask/Clusteringweek6_in_ODM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Clusteringweek6**

# %% [markdown]
# # Euclidean Clustering

# %% [markdown]
# Saya memasukkan 20 dan 21 sebagai feature dan 22 sebagai target dan mengatur samplernya hanya 4% supaya tidak terlalu susah dibaca.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pada saat menampilkannya discatter plot terlihat clusternya seperti terbagi menjadi 3 (Kuning/Hijau/Biru)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Setelah dilakukan Distance dengan Euclidean dengan dinormalisasi didapatkan matrix seperti ini dimana semakin rendah nilainya maka semakin dekat axis x dan axis y yang mana dapat dijadikan cluster

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Hierarchical Clusetering

# %% [markdown]
# Hierarchical Clusetering memasukkan nilai-nilai yang sama pada setiap kategori

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Jika dilihat menggunakan BoxPlot C1 memiliki nilai yang lebih tinggi(Yes) dari cluster lain(No) pada kolom x22

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# Pada K-Means Clustering dapat digunakan k-Means untuk melihat berapa cluster terefisien yang didapat(dalam kasus ini 5, karena Silhoutte scorenya yang paling besar)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ini merupakan visualisasi yang didapat. Dapat dilihat plotnya terbagi menjadi 5 warna berbeda yang mewakili cluster berbeda

# %% [markdown]
# ![image.png](data:image/png;base64,...)
