# %% [markdown]
# <a href="https://colab.research.google.com/github/Dusein/MachineLearningTask/blob/main/6WeekTask/Online_Retail_in_ODM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Online Retail**

# %% [markdown]
# # Euclidean Clustering

# %% [markdown]
# Clustering terhadap CustomerID

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Hierarchical Clusetering

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # DBSCAN

# %% [markdown]
# ![image.png](data:image/png;base64,...)
