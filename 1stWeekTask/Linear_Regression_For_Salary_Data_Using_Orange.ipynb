# %% [markdown]
# <a href="https://colab.research.google.com/github/Dusein/MachineLearningTask/blob/main/1stWeekTask/Linear_Regression_For_Salary_Data_Using_Orange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pertama gunakan "File" untuk memilih file yang akan digunakan, lalu pada bagian column di role ganti Feature 1 menjadi skip karena itu hanya penomoran urut yang tidak berguna untuk dataset. Untuk YearsExperience gunakan sebagai feature dan Salary sebagai target

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lalu masukkan Linear Regression model dan tarik garis untuk menghubungkan keduanya

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lalu masukkan "Test and Score" untuk mengevaluasi nilai dari dataset yang ada.
#
# MSE, RMSE, dan MAE dinyatakan dalam satuan gaji (dalam hal ini dolar) dan memberi tahu seberapa jauh prediksi model dalam hal nilai dolar mentah.
#
# Sebaliknya, MAPE memberi gambaran tentang seberapa jauh prediksi meleset dalam hal persentase.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lalu untuk visualisasinya bisa menggunakan Scatter Plot

# %% [markdown]
# ![image.png](data:image/png;base64,...)
