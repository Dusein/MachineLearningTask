# %% [markdown]
# <a href="https://colab.research.google.com/github/Dusein/MachineLearningTask/blob/main/2ndWeekTask/Logistic_Regression_For_Iris_Dataset_Using_Orange_Data_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Masukkan widget File lalu masukkan file Iris.csv menggunakan File. Lalu ganti pilihan Role pada kolom Species menjadi Target dan pada bagian Id bisa diskip.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lalu masukkan Data Table ke canvas untuk melihat isi data yang sudah dimasukkan

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lalu masukkan model Logistic Regression dan Test and Score untuk mengevaluasi hasil dari logistic regression. Sambungkan Data Table ke Logistic Regression dan Test and Score. Sambungkan juga Logistic Regression ke Test and Score. Didalam Test and Score gunakan Cross Validation untuk pembagian Test dan Train data (Pada gambar digunakan 5x folds).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Untuk Visualisasinya saya menggunakan Scatter Plot dan Confusion Matriks

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
