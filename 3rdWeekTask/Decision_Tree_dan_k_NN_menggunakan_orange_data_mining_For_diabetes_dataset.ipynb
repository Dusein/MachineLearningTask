# %% [markdown]
# <a href="https://colab.research.google.com/github/Dusein/MachineLearningTask/blob/main/3rdWeekTask/Decision_Tree_dan_k_NN_menggunakan_orange_data_mining_For_diabetes_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pertama masukkan widget File dan pilih file yang akan digunakan

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lalu masukkan Data Table untuk melihat isi dataset, lalu masukkan Data Sampler untuk pembagian data train data test, lalu buat 2 jalur untuk masing masing model, pada bagian atas Decision Tree model dengan CA 72.9% akurasi, pada bagian bawah K-NN dengan nilai CA 69.1% akurasi.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Setelah dioprek saya hanya bisa membuat nilai KNN yang melebihi 85% akurasi yaitu 86.2% akurasi, sedangkan pada bagian tree belum bisa dan hanya dapat nilai 77.1% akurasi

# %% [markdown]
# ![image.png](data:image/png;base64,...)
